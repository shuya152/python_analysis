# %%
import requests

url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

try:
    response = requests.get(url)
    response.raise_for_status()  # 檢查HTTP狀態碼，確保請求成功

    data = response.json()  # 將JSON格式的資料轉換為Python字典

    print('YouBike即時資訊下載完成！')

except requests.exceptions.RequestException as e:
    print(f'下載YouBike即時資訊時發生錯誤：{e}')
# Out:
# YouBike即時資訊下載完成！

# %%
import pandas as pd

df = pd.DataFrame(data)
df[["sna",'sarea','mday','ar','available_rent_bikes','available_return_bikes','total']]
# Out:
#                          sna   sarea                 mday             ar  \
# 0         YouBike2.0_捷運科技大樓站     大安區  2025-02-15 16:00:22    復興南路二段235號前
# 1     YouBike2.0_復興南路二段273號前     大安區  2025-02-15 15:53:16   復興南路二段273號西側
# 2       YouBike2.0_國北教大實小東側門     大安區  2025-02-15 15:49:17    和平東路二段96巷7號
# 3          YouBike2.0_和平公園東側     大安區  2025-02-15 15:55:19  和平東路二段118巷33號
# 4       YouBike2.0_辛亥復興路口西北側     大安區  2025-02-15 15:58:21     復興南路二段368號
# ...                      ...     ...                  ...            ...
# 1523      YouBike2.0_臺大禮賢樓西側  臺大公館校區  2025-02-15 15:04:18      臺大禮賢樓西側空地
# 1524    YouBike2.0_臺大大一女餐廳廣場  臺大公館校區  2025-02-15 15:59:18    臺大大一女餐廳廣場後方
# 1525        YouBike2.0_臺大學新館  臺大公館校區  2025-02-15 15:56:18         臺大學新館旁
# 1526     YouBike2.0_臺大水源舍區C棟  臺大公館校區  2025-02-15 15:46:19     臺大水源舍區C棟西側
# 1527        YouBike2.0_臺大人文館  臺大公館校區  2025-02-15 15:58:21       臺大人文館東北側
#
#       available_rent_bikes  available_return_bikes  total
# 0                        0                      28     28
# 1                        0                      21     21
# 2                        8                       8     16
# 3                        2                       9     11
# 4                        4                      12     16
# ...                    ...                     ...    ...
# 1523                    18                      18     36
# 1524                    19                       5     40
# 1525                     5                      28     33
# 1526                    15                      83     99
# 1527                    29                      38     67
#
# [1528 rows x 7 columns]
