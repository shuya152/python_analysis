# %%
import random
students = []
for i in range(1,51):
    students.append(
        {
            'name':f'student{i}',
            'chinese':random.randint(50,100),
            'english':random.randint(50,100),
            'math':random.randint(50,100),
            'history':random.randint(50,100),
            'health':random.randint(50,100)
        }
    )
students
# Out:
# [{'name': 'student1',
#   'chinese': 81,
#   'english': 76,
#   'math': 77,
#   'history': 63,
#   'health': 76},
#  {'name': 'student2',
#   'chinese': 80,
#   'english': 72,
#   'math': 79,
#   'history': 92,
#   'health': 85},
#  {'name': 'student3',
#   'chinese': 97,
#   'english': 82,
#   'math': 88,
#   'history': 62,
#   'health': 81},
#  {'name': 'student4',
#   'chinese': 53,
#   'english': 82,
#   'math': 50,
#   'history': 59,
#   'health': 71},
#  {'name': 'student5',
#   'chinese': 93,
#   'english': 85,
#   'math': 56,
#   'history': 100,
#   'health': 94},
#  {'name': 'student6',
#   'chinese': 82,
#   'english': 65,
#   'math': 87,
#   'history': 66,
#   'health': 72},
#  {'name': 'student7',
#   'chinese': 62,
#   'english': 83,
#   'math': 86,
#   'history': 97,
#   'health': 50},
#  {'name': 'student8',
#   'chinese': 57,
#   'english': 99,
#   'math': 65,
#   'history': 100,
#   'health': 97},
#  {'name': 'student9',
#   'chinese': 84,
#   'english': 97,
#   'math': 88,
#   'history': 87,
#   'health': 53},
#  {'name': 'student10',
#   'chinese': 87,
#   'english': 74,
#   'math': 52,
#   'history': 82,
#   'health': 54},
#  {'name': 'student11',
#   'chinese': 78,
#   'english': 94,
#   'math': 63,
#   'history': 84,
#   'health': 83},
#  {'name': 'student12',
#   'chinese': 79,
#   'english': 67,
#   'math': 93,
#   'history': 62,
#   'health': 81},
#  {'name': 'student13',
#   'chinese': 98,
#   'english': 90,
#   'math': 58,
#   'history': 77,
#   'health': 94},
#  {'name': 'student14',
#   'chinese': 60,
#   'english': 87,
#   'math': 79,
#   'history': 88,
#   'health': 93},
#  {'name': 'student15',
#   'chinese': 60,
#   'english': 53,
#   'math': 76,
#   'history': 99,
#   'health': 89},
#  {'name': 'student16',
#   'chinese': 62,
#   'english': 83,
#   'math': 76,
#   'history': 63,
#   'health': 51},
#  {'name': 'student17',
#   'chinese': 74,
#   'english': 57,
#   'math': 81,
#   'history': 75,
#   'health': 63},
#  {'name': 'student18',
#   'chinese': 60,
#   'english': 78,
#   'math': 57,
#   'history': 80,
#   'health': 53},
#  {'name': 'student19',
#   'chinese': 91,
#   'english': 61,
#   'math': 89,
#   'history': 99,
#   'health': 58},
#  {'name': 'student20',
#   'chinese': 71,
#   'english': 72,
#   'math': 69,
#   'history': 95,
#   'health': 92},
#  {'name': 'student21',
#   'chinese': 63,
#   'english': 72,
#   'math': 100,
#   'history': 67,
#   'health': 56},
#  {'name': 'student22',
#   'chinese': 90,
#   'english': 91,
#   'math': 70,
#   'history': 60,
#   'health': 78},
#  {'name': 'student23',
#   'chinese': 90,
#   'english': 54,
#   'math': 51,
#   'history': 75,
#   'health': 58},
#  {'name': 'student24',
#   'chinese': 100,
#   'english': 86,
#   'math': 83,
#   'history': 84,
#   'health': 63},
#  {'name': 'student25',
#   'chinese': 68,
#   'english': 100,
#   'math': 83,
#   'history': 74,
#   'health': 53},
#  {'name': 'student26',
#   'chinese': 53,
#   'english': 73,
#   'math': 77,
#   'history': 63,
#   'health': 95},
#  {'name': 'student27',
#   'chinese': 96,
#   'english': 76,
#   'math': 55,
#   'history': 50,
#   'health': 98},
#  {'name': 'student28',
#   'chinese': 50,
#   'english': 84,
#   'math': 98,
#   'history': 87,
#   'health': 72},
#  {'name': 'student29',
#   'chinese': 91,
#   'english': 86,
#   'math': 64,
#   'history': 76,
#   'health': 99},
#  {'name': 'student30',
#   'chinese': 98,
#   'english': 84,
#   'math': 96,
#   'history': 98,
#   'health': 96},
#  {'name': 'student31',
#   'chinese': 65,
#   'english': 64,
#   'math': 71,
#   'history': 78,
#   'health': 56},
#  {'name': 'student32',
#   'chinese': 53,
#   'english': 56,
#   'math': 72,
#   'history': 87,
#   'health': 90},
#  {'name': 'student33',
#   'chinese': 74,
#   'english': 76,
#   'math': 64,
#   'history': 93,
#   'health': 72},
#  {'name': 'student34',
#   'chinese': 63,
#   'english': 86,
#   'math': 69,
#   'history': 52,
#   'health': 84},
#  {'name': 'student35',
#   'chinese': 65,
#   'english': 87,
#   'math': 55,
#   'history': 74,
#   'health': 57},
#  {'name': 'student36',
#   'chinese': 55,
#   'english': 59,
#   'math': 55,
#   'history': 60,
#   'health': 92},
#  {'name': 'student37',
#   'chinese': 95,
#   'english': 62,
#   'math': 83,
#   'history': 81,
#   'health': 96},
#  {'name': 'student38',
#   'chinese': 91,
#   'english': 69,
#   'math': 77,
#   'history': 60,
#   'health': 57},
#  {'name': 'student39',
#   'chinese': 78,
#   'english': 86,
#   'math': 98,
#   'history': 71,
#   'health': 57},
#  {'name': 'student40',
#   'chinese': 79,
#   'english': 85,
#   'math': 85,
#   'history': 95,
#   'health': 86},
#  {'name': 'student41',
#   'chinese': 50,
#   'english': 71,
#   'math': 68,
#   'history': 86,
#   'health': 71},
#  {'name': 'student42',
#   'chinese': 87,
#   'english': 59,
#   'math': 65,
#   'history': 50,
#   'health': 52},
#  {'name': 'student43',
#   'chinese': 78,
#   'english': 86,
#   'math': 74,
#   'history': 86,
#   'health': 78},
#  {'name': 'student44',
#   'chinese': 87,
#   'english': 65,
#   'math': 51,
#   'history': 90,
#   'health': 54},
#  {'name': 'student45',
#   'chinese': 78,
#   'english': 83,
#   'math': 71,
#   'history': 53,
#   'health': 78},
#  {'name': 'student46',
#   'chinese': 84,
#   'english': 58,
#   'math': 62,
#   'history': 69,
#   'health': 93},
#  {'name': 'student47',
#   'chinese': 61,
#   'english': 90,
#   'math': 53,
#   'history': 97,
#   'health': 92},
#  {'name': 'student48',
#   'chinese': 52,
#   'english': 94,
#   'math': 52,
#   'history': 50,
#   'health': 87},
#  {'name': 'student49',
#   'chinese': 54,
#   'english': 55,
#   'math': 95,
#   'history': 50,
#   'health': 69},
#  {'name': 'student50',
#   'chinese': 60,
#   'english': 83,
#   'math': 77,
#   'history': 100,
#   'health': 94}]

# %% [markdown]
# * https://docs.python.org/zh-tw/3/library/csv.html

# %%
import csv

file = open('student.csv',mode='w',encoding='utf-8',newline='')
writer =csv.DictWriter(file,["name","chinese","english","math","history","health"])
#print(type(writer))
writer.writeheader()
writer.writerows(students)

file.close()#沒有關起來會浪費資源
#file.closed

# %%
import csv

#用with as就不用另外寫file.close()
with open('student.csv',mode='w',encoding='utf-8',newline='') as file:
    writer =csv.DictWriter(file,["name","chinese","english","math","history","health"])
    writer.writeheader()
    writer.writerows(students)

file.closed
# Out:
# True
